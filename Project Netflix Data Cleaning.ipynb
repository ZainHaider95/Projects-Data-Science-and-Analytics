# %%
import numpy as np
import pandas as pd

# %%
data= pd.read_csv('netflix.csv')

data.head(10)
# Out:
#                    title rating  \
# 0           White Chicks  PG-13
# 1    Lucky Number Slevin      R
# 2         Grey's Anatomy  TV-14
# 3           Prison Break  TV-14
# 4  How I Met Your Mother  TV-PG
# 5           Supernatural  TV-14
# 6           Breaking Bad  TV-MA
# 7    The Vampire Diaries  TV-14
# 8       The Walking Dead  TV-MA
# 9    Pretty Little Liars  TV-14
#
#                                          ratingLevel  ratingDescription  \
# 0  crude and sexual humor, language and some drug...                 80
# 1  strong violence, sexual content and adult lang...                100
# 2  Parents strongly cautioned. May be unsuitable ...                 90
# 3  Parents strongly cautioned. May be unsuitable ...                 90
# 4  Parental guidance suggested. May not be suitab...                 70
# 5  Parents strongly cautioned. May be unsuitable ...                 90
# 6  For mature audiences.  May not be suitable for...                110
# ...

# %%
data.tail(10)
# Out:
#                           title rating  \
# 990           My Animal Friends   TV-Y
# 991          Dawn of the Croods  TV-Y7
# 992  Alpha and Omega: Dino Digs   TV-G
# 993   Wiener Dog Internationals      G
# 994                    Pup Star      G
# 995                     The BFG     PG
# 996     The Secret Life of Pets     PG
# 997            Precious Puppies   TV-G
# 998                 Beary Tales   TV-G
# 999             Growing Up Wild      G
#
#                                            ratingLevel  ratingDescription  \
# 990                             Suitable for all ages.                 10
# 991             Suitable for children ages 7 and older                 41
# 992                             Suitable for all ages.                 35
# 993          General Audiences. Suitable for all ages.                 35
# 994          General Audiences. Suitable for all ages.                 35
# 995  for action/peril, some scary moments and brief...                 60
# ...

# %%
data.isnull()
# Out:
#      title  rating  ratingLevel  ratingDescription  release year  \
# 0    False   False        False              False         False
# 1    False   False        False              False         False
# 2    False   False        False              False         False
# 3    False   False        False              False         False
# 4    False   False        False              False         False
# ..     ...     ...          ...                ...           ...
# 995  False   False        False              False         False
# 996  False   False        False              False         False
# 997  False   False        False              False         False
# 998  False   False        False              False         False
# 999  False   False         True              False         False
#
#      user rating score  user rating size
# 0                False             False
# 1                 True             False
# 2                False             False
# ...

# %%
data.isnull().sum()
# Out:
# title                  0
# rating                 0
# ratingLevel           59
# ratingDescription      0
# release year           0
# user rating score    395
# user rating size       0
# dtype: int64

# %%
data.notnull().sum()
# Out:
# title                1000
# rating               1000
# ratingLevel           941
# ratingDescription    1000
# release year         1000
# user rating score     605
# user rating size     1000
# dtype: int64

# %%
data.shape
# Out:
# (1000, 7)

# %%
data.columns
# Out:
# Index(['title', 'rating', 'ratingLevel', 'ratingDescription', 'release year',
#        'user rating score', 'user rating size'],
#       dtype='object')

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
# In checking locations, Ratings columns has no space so written as data.rating .
# In release year has space so written as data["release year"]

data.loc[(data.rating =='PG-13') & (data["release year"] == 2011)]
# Out:
#             title rating                                        ratingLevel  \
# 273  Mean Girls 2  PG-13  For some rude and suggestive material, and for...
# 322  Mean Girls 2  PG-13  For some rude and suggestive material, and for...
#
#      ratingDescription  release year  user rating score  user rating size
# 273                 80          2011                NaN                82
# 322                 80          2011                NaN                82

# %%
data.loc[ (data.rating =='PG-13') & (data["user rating score"] >= 80) ]
# Out:
#             title rating                                        ratingLevel  \
# 0    White Chicks  PG-13  crude and sexual humor, language and some drug...
# 250  The Waterboy  PG-13               language and some crude sexual humor
# 257      Twilight  PG-13                 some violence and one sexual scene
# 300  The Waterboy  PG-13               language and some crude sexual humor
# 306      Twilight  PG-13                 some violence and one sexual scene
#
#      ratingDescription  release year  user rating score  user rating size
# 0                   80          2004               82.0                80
# 250                 80          1998               82.0                80
# 257                 80          2008               89.0                80
# 300                 80          1998               82.0                80
# 306                 80          2008               89.0                80

# %%
data.loc[(data.rating =='PG-13'),('title','ratingLevel')]
# Out:
#                             title  \
# 0                    White Chicks
# 250                  The Waterboy
# 251    10 Things I Hate About You
# 253  How to Lose a Guy in 10 Days
# 254              The Benchwarmers
# 255                       Step Up
# 257                      Twilight
# 273                  Mean Girls 2
# 286                    Safe Haven
# 300                  The Waterboy
# 302           The Wedding Planner
# 306                      Twilight
# 322                  Mean Girls 2
# 335        Trouble with the Curve
# 372                 Unconditional
#
#                                            ratingLevel
# 0    crude and sexual humor, language and some drug...
# 250               language and some crude sexual humor
# 251    adult content, adult language and mild violence
# 253                          some sex-related material
# 254       crude and suggestive humor, and for language
# 255     thematic elements, brief violence and innuendo
# ...

# %%
# iloc [rows, columns]


data.iloc[2:7 , 0:2]
# Out:
#                    title rating
# 2         Grey's Anatomy  TV-14
# 3           Prison Break  TV-14
# 4  How I Met Your Mother  TV-PG
# 5           Supernatural  TV-14
# 6           Breaking Bad  TV-MA

# %%
data.iloc[7 ,2]
# Out:
# 'Parents strongly cautioned. May be unsuitable for children ages 14 and under.'

# %%
data.iloc[0:4 ,:-1]
# Out:
#                  title rating  \
# 0         White Chicks  PG-13
# 1  Lucky Number Slevin      R
# 2       Grey's Anatomy  TV-14
# 3         Prison Break  TV-14
#
#                                          ratingLevel  ratingDescription  \
# 0  crude and sexual humor, language and some drug...                 80
# 1  strong violence, sexual content and adult lang...                100
# 2  Parents strongly cautioned. May be unsuitable ...                 90
# 3  Parents strongly cautioned. May be unsuitable ...                 90
#
#    release year  user rating score
# 0          2004               82.0
# 1          2006                NaN
# 2          2016               98.0
# 3          2008               98.0

# %%
data.describe()
# Out:
#        ratingDescription  release year  user rating score  user rating size
# count         1000.00000   1000.000000         605.000000       1000.000000
# mean            67.36600   2010.335000          84.094215         80.783000
# std             30.78561      8.877927          12.344371          0.973066
# min             10.00000   1940.000000          55.000000         80.000000
# 25%             35.00000   2007.000000          75.000000         80.000000
# 50%             60.00000   2015.000000          88.000000         80.000000
# 75%             90.00000   2016.000000          95.000000         82.000000
# max            124.00000   2017.000000          99.000000         82.000000

# %% [markdown]
# # Cleaning Data [Removing Null Values & Filling New Values]

# %%
data.isnull().sum()
# Out:
# title                  0
# rating                 0
# ratingLevel           59
# ratingDescription      0
# release year           0
# user rating score    395
# user rating size       0
# dtype: int64

# %%
data['user rating score'].mean()
# Out:
# 84.09421487603306

# %%
# Replace Values with Rounding off main value 84.
# df['column name'].replace(['old value'],'new value', inplace= True)
# np.nan REPRESENTS NULL Value, 'NaN'

data['user rating score'].replace(np.nan, 84, inplace= True)

# %%
data.isnull().sum()
# Out:
# title                 0
# rating                0
# ratingLevel          59
# ratingDescription     0
# release year          0
# user rating score     0
# user rating size      0
# dtype: int64

# %%
data['ratingLevel']
# Out:
# 0      crude and sexual humor, language and some drug...
# 1      strong violence, sexual content and adult lang...
# 2      Parents strongly cautioned. May be unsuitable ...
# 3      Parents strongly cautioned. May be unsuitable ...
# 4      Parental guidance suggested. May not be suitab...
#                              ...
# 995    for action/peril, some scary moments and brief...
# 996                       for action and some rude humor
# 997                               Suitable for all ages.
# 998                               Suitable for all ages.
# 999                                                  NaN
# Name: ratingLevel, Length: 1000, dtype: object

# %%
data['ratingLevel'].replace(np.nan, 'Not Rated', inplace= True)

# %%
data['ratingLevel']
# Out:
# 0      crude and sexual humor, language and some drug...
# 1      strong violence, sexual content and adult lang...
# 2      Parents strongly cautioned. May be unsuitable ...
# 3      Parents strongly cautioned. May be unsuitable ...
# 4      Parental guidance suggested. May not be suitab...
#                              ...
# 995    for action/peril, some scary moments and brief...
# 996                       for action and some rude humor
# 997                               Suitable for all ages.
# 998                               Suitable for all ages.
# 999                                            Not Rated
# Name: ratingLevel, Length: 1000, dtype: object

# %%
data.isnull().sum()
# Out:
# title                0
# rating               0
# ratingLevel          0
# ratingDescription    0
# release year         0
# user rating score    0
# user rating size     0
# dtype: int64
